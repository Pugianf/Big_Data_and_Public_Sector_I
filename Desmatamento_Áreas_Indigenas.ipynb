# %% [markdown]
# <a href="https://colab.research.google.com/github/Pugianf/Big_Data_and_Public_Sector_I/blob/main/Desmatamento_%C3%81reas_Indigenas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

# %%
df = pd.read_csv('/content/drive/MyDrive/IDP/Dataset/terrabrasilis_legal_amazon_1_11_2021_1638405170860.csv', sep=';')

# %%
df
# Out:
#       year area km²                             indi
# 0     2021     0,70            Kanamari do Rio Juruá
# 1     2021     2,18                     Andirá-Marau
# 2     2021     0,00      Apurinã do Igarapé São João
# 3     2021     0,43                         Pinatuba
# 4     2021     0,21                        Mãe Maria
# ...    ...      ...                              ...
# 2523  2008     0,09       Jarawara/Jamamadi/Kanamati
# 2524  2008     1,34                        Rio Urubu
# 2525  2008     1,21                  Vale do Guaporé
# 2526  2008     2,80  Porquinhos dos Canela-Apãnjekra
# 2527  2008     0,08                       Trincheira
#
# [2528 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2528 entries, 0 to 2527
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      2528 non-null   int64
#  1   area km²  2528 non-null   object
#  2   indi      2528 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 59.4+ KB

# %%
df.groupby(by=['indi', 'year']).sum().head(10)
# Out:
#                        area km²
# indi            year
# Acapuri de Cima 2010       0,23
# Acimã           2016       0,12
#                 2020       0,08
# Alto Rio Guamá  2008       5,73
#                 2009  0,0041,14
#                 2010       5,90
#                 2011  0,0118,62
#                 2012       1,43
#                 2013       1,52
#                 2014   0,016,63

# %%
df.rename(columns={'area km²': 'area'}, inplace=True)

# %%
df
# Out:
#       year  area                             indi
# 0     2021  0,70            Kanamari do Rio Juruá
# 1     2021  2,18                     Andirá-Marau
# 2     2021  0,00      Apurinã do Igarapé São João
# 3     2021  0,43                         Pinatuba
# 4     2021  0,21                        Mãe Maria
# ...    ...   ...                              ...
# 2523  2008  0,09       Jarawara/Jamamadi/Kanamati
# 2524  2008  1,34                        Rio Urubu
# 2525  2008  1,21                  Vale do Guaporé
# 2526  2008  2,80  Porquinhos dos Canela-Apãnjekra
# 2527  2008  0,08                       Trincheira
#
# [2528 rows x 3 columns]

# %%
df['area'] = df['area'].apply(lambda x: x.replace(',','.'))

# %%
df['area'] = df['area'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2528 entries, 0 to 2527
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    2528 non-null   int64
#  1   area    2528 non-null   float64
#  2   indi    2528 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 59.4+ KB

# %%
df.groupby(by=['indi', 'year']).sum().head(50)

# %%
terras_indigenas = df.indi.unique()

# %%
len(terras_indigenas)
# Out:
# 315

# %%
terras_indigenas
# Out:
# array(['Kanamari do Rio Juruá', 'Andirá-Marau',
#        'Apurinã do Igarapé São João', 'Pinatuba', 'Mãe Maria', 'Tumiã',
#        'Apurinã Igarapé Tauamirim', 'Xikrin do Rio Catete', 'Manoki',
#        'Munduruku', 'Sete de Setembro', 'Lago do Limão',
#        'Piripkura ( restrição de uso )', 'Trombetas/Mapuera', 'Panará',
#        'Bacurizinho', 'Alto Sepatini', 'Apinayé',
#        'Jacareúba/Katauixi (restrição uso)', 'Coata-Laranjal',
#        'Roosevelt', 'Paquiçamba', 'Mawetek', 'Paumari do Lago Marahã',
#        'Malacacheta', 'Kayabi', 'Apurinã Km 124 BR-317', 'Koatinemo',
#        'Geralda Toco Preto', 'Karipuna', 'Rio Mequens', 'Igarapé Lage',
#        'WaiWái', 'Ponciano', 'Água Preta/Inari', 'Karitiana',
#        'Murutinga/Tracaja', 'Igarapé Lourdes', 'Arara', 'Camicua',
#        'Cachoeira Seca', 'Parakanã', 'Munduruku-Taquara', 'Enawenê-Nawê',
#        'Arara do Rio Branco', 'Tenharim do Igarapé Preto',
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/IDP/Dataset/Pasta1.csv', sep = ';', error_bad_lines=False)

# %%
df2
# Out:
#                     Nome        Jurisdição Legal Área (ha) População
# 0        Acapuri de Cima          Amazônia Legal     19400       237
# 1                  Acimã          Amazônia Legal     40686        89
# 2                  Aconã  Domínio Mata Atlântica       268        78
# 3            Água Grande  Domínio Mata Atlântica       165        53
# 4             Água Limpa                  Outros         -      2888
# ..                   ...                     ...       ...       ...
# 721   Yvyporã Laranjinha  Domínio Mata Atlântica      1238       184
# 722  YwyPorã/Posto Velho                  Outros         -         -
# 723                 Zo´é          Amazônia Legal    668565       315
# 724                 Zoró          Amazônia Legal    355789       711
# 725              Zuruahã          Amazônia Legal    239070       156
#
# [726 rows x 4 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nome              726 non-null    object
#  1   Jurisdição Legal  717 non-null    object
#  2   Área (ha)         726 non-null    object
#  3   População         726 non-null    object
# dtypes: object(4)
# memory usage: 22.8+ KB

# %%
df2['Área (ha)'] = df2['Área (ha)'].apply(lambda x: x.replace('-', 'NaN'))

# %%
df2
# Out:
#                     Nome        Jurisdição Legal Área (ha) População
# 0        Acapuri de Cima          Amazônia Legal     19400       237
# 1                  Acimã          Amazônia Legal     40686        89
# 2                  Aconã  Domínio Mata Atlântica       268        78
# 3            Água Grande  Domínio Mata Atlântica       165        53
# 4             Água Limpa                  Outros       NaN      2888
# ..                   ...                     ...       ...       ...
# 721   Yvyporã Laranjinha  Domínio Mata Atlântica      1238       184
# 722  YwyPorã/Posto Velho                  Outros       NaN         -
# 723                 Zo´é          Amazônia Legal    668565       315
# 724                 Zoró          Amazônia Legal    355789       711
# 725              Zuruahã          Amazônia Legal    239070       156
#
# [726 rows x 4 columns]

# %%
df2['Área (ha)'] = df2['Área (ha)'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-9701c63d5ffa> in <module>()
# ----> 1 df2['Área (ha)'] = df2['Área (ha)'].astype(int)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
df2['Área (ha)'] = df2['Área (ha)'].apply(pd.to_numeric, errors='coerce')

# %%
df2
# Out:
#                     Nome        Jurisdição Legal  Área (ha) População
# 0        Acapuri de Cima          Amazônia Legal    19400.0       237
# 1                  Acimã          Amazônia Legal    40686.0        89
# 2                  Aconã  Domínio Mata Atlântica      268.0        78
# 3            Água Grande  Domínio Mata Atlântica      165.0        53
# 4             Água Limpa                  Outros        NaN      2888
# ..                   ...                     ...        ...       ...
# 721   Yvyporã Laranjinha  Domínio Mata Atlântica     1238.0       184
# 722  YwyPorã/Posto Velho                  Outros        NaN         -
# 723                 Zo´é          Amazônia Legal   668565.0       315
# 724                 Zoró          Amazônia Legal   355789.0       711
# 725              Zuruahã          Amazônia Legal   239070.0       156
#
# [726 rows x 4 columns]

# %%
df = df.rename(columns={'indi': 'nome'})

# %%
df
# Out:
#       year  area                             nome
# 0     2021  0.70            Kanamari do Rio Juruá
# 1     2021  2.18                     Andirá-Marau
# 2     2021  0.00      Apurinã do Igarapé São João
# 3     2021  0.43                         Pinatuba
# 4     2021  0.21                        Mãe Maria
# ...    ...   ...                              ...
# 2523  2008  0.09       Jarawara/Jamamadi/Kanamati
# 2524  2008  1.34                        Rio Urubu
# 2525  2008  1.21                  Vale do Guaporé
# 2526  2008  2.80  Porquinhos dos Canela-Apãnjekra
# 2527  2008  0.08                       Trincheira
#
# [2528 rows x 3 columns]

# %%
df1 = df.groupby(by='nome').sum().reset_index()

# %%
df1.rename(columns={'nome':'Nome'}, inplace=True)

# %%
result = pd.merge(df1, df2, on='Nome')

# %%
df2[df2['Jurisdição Legal'] == 'Amazônia Legal'].head(25)
# Out:
#                             Nome Jurisdição Legal  Área (ha) População
# 0                Acapuri de Cima   Amazônia Legal    19400.0       237
# 1                          Acimã   Amazônia Legal    40686.0        89
# 5               Água Preta/Inari   Amazônia Legal   139763.0       349
# 7              Aldeia Beija Flor   Amazônia Legal       41.0       574
# 14                Alto Rio Guamá   Amazônia Legal   279897.0      1727
# 15                Alto Rio Negro   Amazônia Legal  7999380.0     26046
# 16                Alto Rio Purus   Amazônia Legal   263129.0      1871
# 17                 Alto Sepatini   Amazônia Legal    26095.0        75
# 18                 Alto Tarauacá   Amazônia Legal   142619.0         -
# 19                  Alto Turiaçu   Amazônia Legal   530525.0      1500
# 22                        Anambé   Amazônia Legal     7883.0       161
# 23                        Ananás   Amazônia Legal     1769.0         9
# ...

# %%
df1.head(25)
# Out:
#                               Nome   year    area
# 0                  Acapuri de Cima   2010    0.23
# 1                            Acimã   4036    0.20
# 2                   Alto Rio Guamá  34237  101.67
# 3                   Alto Rio Negro  26182   25.74
# 4                   Alto Rio Purus  26188    3.12
# 5                    Alto Sepatini   4034    0.28
# 6                    Alto Tarauacá   2010    0.05
# 7                     Alto Turiaçu  28203   78.07
# 8                           Anambé  16100    1.28
# 9                     Andirá-Marau  54391   43.74
# 10                         Aningal  14108    0.91
# 11                            Anta   4032    0.16
# 12                   Apiaka/Kayabi  18119    7.24
# 13     Apiaká do Pontal e Isolados   8062    1.32
# 14                         Apinayé  20134    1.12
# 15       Apurinã Igarapé Tauamirim   2021    0.14
# 16           Apurinã Km 124 BR-317  28203   11.71
# 17       Apurinã do Igarapé Mucuim   6040    0.44
# ...

# %%
result.head(25)
# Out:
#                               Nome   year  ...  Área (ha) População
# 0                  Acapuri de Cima   2010  ...    19400.0       237
# 1                            Acimã   4036  ...    40686.0        89
# 2                   Alto Rio Guamá  34237  ...   279897.0      1727
# 3                   Alto Rio Negro  26182  ...  7999380.0     26046
# 4                   Alto Rio Purus  26188  ...   263129.0      1871
# 5                    Alto Sepatini   4034  ...    26095.0        75
# 6                    Alto Tarauacá   2010  ...   142619.0         -
# 7                     Alto Turiaçu  28203  ...   530525.0      1500
# 8                           Anambé  16100  ...     7883.0       161
# 9                     Andirá-Marau  54391  ...   788528.0     13350
# 10                         Aningal  14108  ...     7627.0       245
# 11                            Anta   4032  ...     3173.0       183
# 12     Apiaká do Pontal e Isolados   8062  ...   982324.0       262
# ...

# %%
lista1 = []

for i in terras_indigenas:
  if i in result['Nome']:
    continue
  else:
    lista1.append(i)

# %%
len(lista1)
# Out:
# 315

# %%
# !pip install unidecode

from unidecode import unidecode
# Out:
# ...
#      |████████████████████████████████| 235 kB 9.4 MB/s
# ...

# %%
df1['normalizado'] = df1.Nome.str.normalize('NFKD')

# %%
df1
# Out:
#                  Nome   year    area        normalizado
# 0     Acapuri de Cima   2010    0.23    Acapuri de Cima
# 1               Acimã   4036    0.20             Acimã
# 2      Alto Rio Guamá  34237  101.67    Alto Rio Guamá
# 3      Alto Rio Negro  26182   25.74     Alto Rio Negro
# 4      Alto Rio Purus  26188    3.12     Alto Rio Purus
# ..                ...    ...     ...                ...
# 310              Zoró  28203   75.31              Zoró
# 311           Zuruahã  20143    3.21           Zuruahã
# 312  Água Preta/Inari  20154    1.25  Água Preta/Inari
# 313           Évare I  24170   11.94           Évare I
# 314          Évare II  24174    3.85          Évare II
#
# [315 rows x 4 columns]

# %%
def simplify(text):
	import unicodedata
	try:
		text = unicode(text, 'utf-8')
	except NameError:
		pass
	text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
	return str(text)

# %%
df1['normalize'] = df1.Nome.apply(simplify)

# %%
df1.normalize = df1.normalize.apply(lambda x: x.strip().lower())

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–", " "]
for char in spec_chars:
    df1.normalize = df1.normalize.str.replace(char, '')

# %%
df1
# Out:
#                  Nome   year    area        normalizado       normalize
# 0     Acapuri de Cima   2010    0.23    Acapuri de Cima   acapuridecima
# 1               Acimã   4036    0.20             Acimã           acima
# 2      Alto Rio Guamá  34237  101.67    Alto Rio Guamá    altorioguama
# 3      Alto Rio Negro  26182   25.74     Alto Rio Negro    altorionegro
# 4      Alto Rio Purus  26188    3.12     Alto Rio Purus    altoriopurus
# ..                ...    ...     ...                ...             ...
# 310              Zoró  28203   75.31              Zoró            zoro
# 311           Zuruahã  20143    3.21           Zuruahã         zuruaha
# 312  Água Preta/Inari  20154    1.25  Água Preta/Inari  aguapretainari
# 313           Évare I  24170   11.94           Évare I          evarei
# 314          Évare II  24174    3.85          Évare II         evareii
#
# [315 rows x 5 columns]

# %%
df1
# Out:
#                  Nome   year    area        normalizado         normalize
# 0     Acapuri de Cima   2010    0.23    Acapuri de Cima   acapuri de cima
# 1               Acimã   4036    0.20             Acimã             acima
# 2      Alto Rio Guamá  34237  101.67    Alto Rio Guamá    alto rio guama
# 3      Alto Rio Negro  26182   25.74     Alto Rio Negro    alto rio negro
# 4      Alto Rio Purus  26188    3.12     Alto Rio Purus    alto rio purus
# ..                ...    ...     ...                ...               ...
# 310              Zoró  28203   75.31              Zoró              zoro
# 311           Zuruahã  20143    3.21           Zuruahã           zuruaha
# 312  Água Preta/Inari  20154    1.25  Água Preta/Inari  agua preta/inari
# 313           Évare I  24170   11.94           Évare I           evare i
# 314          Évare II  24174    3.85          Évare II          evare ii
#
# [315 rows x 5 columns]

# %%
df2
# Out:
#                     Nome        Jurisdição Legal  Área (ha) População
# 0        Acapuri de Cima          Amazônia Legal    19400.0       237
# 1                  Acimã          Amazônia Legal    40686.0        89
# 2                  Aconã  Domínio Mata Atlântica      268.0        78
# 3            Água Grande  Domínio Mata Atlântica      165.0        53
# 4             Água Limpa                  Outros        NaN      2888
# ..                   ...                     ...        ...       ...
# 721   Yvyporã Laranjinha  Domínio Mata Atlântica     1238.0       184
# 722  YwyPorã/Posto Velho                  Outros        NaN         -
# 723                 Zo´é          Amazônia Legal   668565.0       315
# 724                 Zoró          Amazônia Legal   355789.0       711
# 725              Zuruahã          Amazônia Legal   239070.0       156
#
# [726 rows x 4 columns]

# %%
df2['normalize'] = df2.Nome.apply(simplify)

# %%
df2['normalize'] = df2['normalize'].apply(lambda x: x.strip().lower())

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–", " "]
for char in spec_chars:
    df2['normalize'] = df2['normalize'].str.replace(char, '')

# %%
df2
# Out:
#                     Nome        Jurisdição Legal  ...  População          normalize
# 0        Acapuri de Cima          Amazônia Legal  ...        237      acapuridecima
# 1                  Acimã          Amazônia Legal  ...         89              acima
# 2                  Aconã  Domínio Mata Atlântica  ...         78              acona
# 3            Água Grande  Domínio Mata Atlântica  ...         53         aguagrande
# 4             Água Limpa                  Outros  ...       2888          agualimpa
# ..                   ...                     ...  ...        ...                ...
# 721   Yvyporã Laranjinha  Domínio Mata Atlântica  ...        184  yvyporalaranjinha
# 722  YwyPorã/Posto Velho                  Outros  ...          -  ywyporapostovelho
# 723                 Zo´é          Amazônia Legal  ...        315                zoe
# 724                 Zoró          Amazônia Legal  ...        711               zoro
# ...

# %%
result = pd.merge(df1, df2, on='normalize')

# %%
result
# Out:
#                Nome_x   year    area  ... Jurisdição Legal  Área (ha) População
# 0     Acapuri de Cima   2010    0.23  ...   Amazônia Legal    19400.0       237
# 1               Acimã   4036    0.20  ...   Amazônia Legal    40686.0        89
# 2      Alto Rio Guamá  34237  101.67  ...   Amazônia Legal   279897.0      1727
# 3      Alto Rio Negro  26182   25.74  ...   Amazônia Legal  7999380.0     26046
# 4      Alto Rio Purus  26188    3.12  ...   Amazônia Legal   263129.0      1871
# ..                ...    ...     ...  ...              ...        ...       ...
# 281              Zoró  28203   75.31  ...   Amazônia Legal   355789.0       711
# 282           Zuruahã  20143    3.21  ...   Amazônia Legal   239070.0       156
# 283  Água Preta/Inari  20154    1.25  ...   Amazônia Legal   139763.0       349
# 284           Évare I  24170   11.94  ...   Amazônia Legal   548177.0     18086
# 285          Évare II  24174    3.85  ...   Amazônia Legal   176205.0      2347
#
# ...

# %%
result.drop(['normalizado', 'normalize', 'Nome_y'], axis=1, inplace=True)

# %%
result
# Out:
#                Nome_x   year    area Jurisdição Legal  Área (ha) População
# 0     Acapuri de Cima   2010    0.23   Amazônia Legal    19400.0       237
# 1               Acimã   4036    0.20   Amazônia Legal    40686.0        89
# 2      Alto Rio Guamá  34237  101.67   Amazônia Legal   279897.0      1727
# 3      Alto Rio Negro  26182   25.74   Amazônia Legal  7999380.0     26046
# 4      Alto Rio Purus  26188    3.12   Amazônia Legal   263129.0      1871
# ..                ...    ...     ...              ...        ...       ...
# 281              Zoró  28203   75.31   Amazônia Legal   355789.0       711
# 282           Zuruahã  20143    3.21   Amazônia Legal   239070.0       156
# 283  Água Preta/Inari  20154    1.25   Amazônia Legal   139763.0       349
# 284           Évare I  24170   11.94   Amazônia Legal   548177.0     18086
# 285          Évare II  24174    3.85   Amazônia Legal   176205.0      2347
#
# [286 rows x 6 columns]

# %%
df1.rename(columns={'Nome':'Nome_x'}).Nome
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-190-9e8c35400065> in <module>()
# ----> 1 df1.rename(columns={'Nome':'Nome_x'}).Nome
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Nome'

# %%
result.Nome_x.compare(df1.rename(columns={'Nome':'Nome_x'}).Nome_x, keep_shape=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-911f35f9623c> in <module>()
# ----> 1 result.Nome_x.compare(df1.rename(columns={'Nome':'Nome_x'}).Nome_x, keep_shape=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in compare(self, other, align_axis, keep_shape, keep_equal)
#    2850             align_axis=align_axis,
#    2851             keep_shape=keep_shape,
# -> 2852             keep_equal=keep_equal,
#    2853         )
#    2854
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in compare(self, other, align_axis, keep_shape, keep_equal)
#    8396             )
#    8397
# -> 8398         mask = ~((self == other) | (self.isna() & other.isna()))
#    8399         keys = ["self", "other"]
#    8400
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
# ...

# %%
result2 = pd.merge(df1, df2, on='normalize')

# %%
result2
# Out:
#                Nome_x   year    area  ... Jurisdição Legal  Área (ha) População
# 0     Acapuri de Cima   2010    0.23  ...   Amazônia Legal    19400.0       237
# 1               Acimã   4036    0.20  ...   Amazônia Legal    40686.0        89
# 2      Alto Rio Guamá  34237  101.67  ...   Amazônia Legal   279897.0      1727
# 3      Alto Rio Negro  26182   25.74  ...   Amazônia Legal  7999380.0     26046
# 4      Alto Rio Purus  26188    3.12  ...   Amazônia Legal   263129.0      1871
# ..                ...    ...     ...  ...              ...        ...       ...
# 281              Zoró  28203   75.31  ...   Amazônia Legal   355789.0       711
# 282           Zuruahã  20143    3.21  ...   Amazônia Legal   239070.0       156
# 283  Água Preta/Inari  20154    1.25  ...   Amazônia Legal   139763.0       349
# 284           Évare I  24170   11.94  ...   Amazônia Legal   548177.0     18086
# 285          Évare II  24174    3.85  ...   Amazônia Legal   176205.0      2347
#
# ...

# %%
faltantes = []

for i in list(df1.Nome):
  if i not in (list(result2.Nome_x)):
    faltantes.append(i)

# %%
len(faltantes)
# Out:
# 30

# %%
faltantes
# Out:
# ['Apurinã Igarapé Tauamirim',
#  'Arara do Igarapé Humaitá',
#  'Cana Brava/Guajajara',
#  'Ituna/Itatá (restrição de uso)',
#  'Jabuti',
#  'Jacareúba/Katauixi (restrição uso)',
#  'Jaminaua/Envira',
#  'Jarawara/Jamamadi/Kanamati',
#  'Kampa do Rio Amônia',
#  'Kaxinawá da Praia do Carapanã',
#  'Kaxinawá do Baixo Rio Jordão',
#  'Kulina Igarapé do Pau',
#  'Lago do Beruri',
#  'Maracaxi',
#  'Munduruku',
#  'Nambikwara',
#  'Parque do Araguaia',
#  'Parque do Aripuanã',
#  'Parque do Tumucumaque',
#  'Parque do Xingu',
#  'Piripkura ( restrição de uso )',
#  'Porquinhos dos Canela-Apãnjekra',
#  'Santa Inez',
#  'São Marcos - RR',
#  'Tanaru ( restrição de uso )',
#  'Tikúna de Feijoal',
#  'Tukuna Porto Espiritual',
#  'Uaçá',
#  'Uty-Xunaty',
#  'Xikrin do Rio Catete']

# %%
df2.head(25)
# Out:
#                                               Nome  ...                                       normalize
# 0                                  Acapuri de Cima  ...                                 acapuri de cima
# 1                                            Acimã  ...                                           acima
# 2                                            Aconã  ...                                           acona
# 3                                      Água Grande  ...                                     agua grande
# 4                                       Água Limpa  ...                                      agua limpa
# 5                                 Água Preta/Inari  ...                                agua preta/inari
# 6                                      Águas Belas  ...                                     aguas belas
# 7                                Aldeia Beija Flor  ...                               aldeia beija flor
# ...

# %%
import plotly.graph_objects as go

# %%
label = ["Coal", "Gas", "Hydro", "Nuclear", "Solar & Wind", "Oil","Total Electricity generated"]  #total nodes involved in the graph

#creating a sankey diagram using plotly
fig = go.Figure(data=[go.Sankey(       
    node = dict(            #editing properties of the node
      thickness = 15,
      line = dict(color = "black"),
      label = ["Coal", "Gas", "Hydro", "Nuclear", "Solar & Wind", "Oil","Total Electricity generated"], #total nodes
    ),
    #editing properties of the connecting link
    link = dict(               
      source = [0,1,2,3,4,5],  #source nodes
      target = [6, 6, 6, 6, 6, 6],   #target node
      value = [10146, 6141, 5073, 2670, 1869, 801,26700],  #value of the links
      color = '#eee0e5'
  ))])

#setting figure title and font style
fig.update_layout(title_text="Sources of electricity genration in 2018", font=dict(size = 12, color = 'maroon'),paper_bgcolor='AliceBlue')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e8133da7-9d98-4444-a7bc-2c949b2afdfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e8133da7-9d98-4444-a7bc-2c949b2afdfb")) {
#                     Plotly.newPlot(
#                         'e8133da7-9d98-4444-a7bc-2c949b2afdfb',
# ...
